# %%
with open('test3.txt', 'w') as file:
    print('문자열을 입력하세요. quit 입력시 종료')
    while True:
        msg = input()
        if msg.lower() == "quit":
            break
        file.write(f'{msg}\n')
# Out:
# 문자열을 입력하세요. quit 입력시 종료
