# %% [markdown]
# 구구단(함수로 만들기)

# %%
# 구구단 함수
def gugudan(dan):    # 함수 정의
    print(f'[ 구구단 {dan}단 ]')
    for i in range(1,10):
        print(f'{dan} X {i} = {dan*i}')

# %%
num = int(input('숫자를 입력하세요 : '))
gugudan(num)   # 함수 호출
# Out:
# 숫자를 입력하세요 :  3
# [ 구구단 3단 ]
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27

# %%
for i in range(2,10):
    gugudan(i)
    print()
# Out:
# [ 구구단 2단 ]
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
#
# [ 구구단 3단 ]
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
#
# [ 구구단 4단 ]
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
#
# [ 구구단 5단 ]
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
#
# [ 구구단 6단 ]
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
#
# [ 구구단 7단 ]
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
#
# [ 구구단 8단 ]
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
#
# [ 구구단 9단 ]
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81

# %%
for i in range(2,10):
    print(f'[ 구구단 {i}단 ]')
    for j in range(1,10):
        print(f'{i} X {j} = {i*j}')
    print()
# Out:
# [ 구구단 2단 ]
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
#
# [ 구구단 3단 ]
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
#
# [ 구구단 4단 ]
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
#
# [ 구구단 5단 ]
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
#
# [ 구구단 6단 ]
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
#
# [ 구구단 7단 ]
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
#
# [ 구구단 8단 ]
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
#
# [ 구구단 9단 ]
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81

# %% [markdown]
# 정수형 배열에 저장된 모든 값 더하여 반환

# %%
#정수형 리스트의 총합
numlist = [1,43,25,33]

def getSum(numlist):
    sum = 0
    for n in numlist:
        sum += n
    return sum

sum = getSum(numlist)
print(sum)
# Out:
# 102

# %%
numlist = list(map(int,input("총합을 숫자 목록: ").split()))
sum = getSum(numlist)
print(sum)
# Out:
# 총합을 숫자 목록:  34 25 64 23
# 146

# %%
# namespace, scope

a = 1
def vartest():
    global a
    a += 1
    print(a)
    
vartest()
# Out:
# 2

# %%
# local -> global -> built-in namespace
str1 = '전역변수'
#len = 5 이걸 사용하면 에러가 난다
length = len(str1)
print(length)
# Out:
# 4

# %%
# 함수의 반환값을 여러 개 로 만들기 -> 실제로는 반환값은 한 개임
def add_and_mul(a,b):
    sum = a + b
    mul = a * b
    return sum, mul

result = add_and_mul(3,4)
print(result)

sum, mul = add_and_mul(3,4)
print(sum, mul)

sum, _ = add_and_mul(3,4)
print(sum)
# Out:
# (7, 12)
# 7 12
# 7

# %% [markdown]
# 배열에 저장된 숫자 중 입력된 숫자보다 큰 수가 몇 개 있는지 구하기

# %%
def getCountList(numlist,num):
    count = 0
    for n in numlist:
        if num < n:
            count += 1
    print(count)

# %%
# 입력된 N까지의 정수를 합하는 함수
def sum(N):
    sum = 0
    for i in range(1,N+1):
        sum += i
    return sum
    
print(sum(5))
# Out:
# 15

# %%
# sum(N)을 재귀함수로 만들기
def sum_recursive(N):
    # base condition
    if N == 1: return 1
    
    # 재귀적인 분해, 조합
    return sum_recursive(N-1) + N

# %%
def fact_r(N):
    # base condition
    if N <= 1: return 1

    # 재귀적인 분해, 조합
    return N * fact_r(N-1)
    
N = int(input())
print(fact_r(N))
# Out:
#  0
# 1

# %%
#피보나치 수 5 boj 10870

def fibo_r(N):
    # base condition
    if N == 0: return 0
    if N == 1: return 1
    #재귀적인 분해, 조합
    result = fibo_r(N-1) + fibo_r(N-2)
    return result

N = int(input())
print(fibo_r(N))
# Out:
#  10
# 55

# %%
def palin(strlist, i, j):
    global count
    count += 1  # 함수가 호출될 때마다 카운트 1 증가
    
    # 1. Base condition: 인덱스 i가 j와 같거나 커지면 (가운데까지 무사히 검사 완료)
    if i >= j:
        return 1
    # 2. 양 끝의 문자가 다르다면 팰린드롬이 아님
    elif strlist[i] != strlist[j]:
        return 0
    # 3. 양 끝 문자가 같다면, 안쪽 문자를 검사하기 위해 재귀 호출
    else:
        return palin(strlist, i + 1, j - 1)

def isPalindrome(strlist):
    return palin(strlist, 0, len(strlist) - 1)

num = int(input())

for _ in range(num):
    count = 0  
    
    word = input() 
    
    # 팰린드롬 여부 결과와, 실행 횟수(count)를 함께 출력
    print(isPalindrome(word), count)
# Out:
#  5
#  AAA
# 1 2
#  ABBA
# 1 3
#  ABABA
# 1 3
#  ABCA
# 0 2
#  PALINDROME
# 0 1
