# %%
# "Hello" 문장을 5번 출력하는 코드를 작성

print("Hello")
print("Hello")
print("Hello")
print("Hello")
print("Hello")

# %%
count = 0
while True :
    print("Hello")  # 무한 루프
    count += 1
    if count == 5:
        break
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
count = 0
while count < 5 :
    print("Hello")
    count += 1

# %%
for i in range(0, 5, 1): # range(start, stop, step) 0부터 5가 되면 나가고 1씩 증가한다.
    print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
