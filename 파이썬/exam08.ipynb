# %%
a = list(range(5))  # 리스트 타입으로 변환시키는 방법
print(a)
# Out:
# [0, 1, 2, 3, 4]

# %%
for i in list(range(5)):
    print(i)

#for i in [0,1,2,3,4]:
#    print(i)

# %%
a = [10,20,'A',10.45,True,'hello']
print(a, type(a))
print(20 in a)  # 리스트 안에 있는 원소를 확인하는 방법
a.append('add') # 리스트에 추가하는 방법
print(a)
print(a[0],a[1])
a.remove(20)
print(a)
# Out:
# [10, 20, 'A', 10.45, True, 'hello'] <class 'list'>
# True
# [10, 20, 'A', 10.45, True, 'hello', 'add']
# 10 20
# [10, 'A', 10.45, True, 'hello', 'add']
