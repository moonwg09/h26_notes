# %% [markdown]
# 만일 동전이 필요없다면 출력에서 제외
#
# 물건값을 입력하시오 : 6370
# 지불한 돈의 액수를 입력하시오 : 10000
#
# 거스름돈 : 3630원
# 1000원 : 3개
#  500원 : 1개
#  100원 : 1개
#   10원 : 3개

# %%
# total = int(input('물건을 값을 입력하시오'))
# money = int(input('지불한 돈의 액수를 입력하시오'))

total = 4150
money = 10000

change = money - total
if change >= 0 : 
    print(f'거스름돈 : {change}원이다')

    n1000 = change // 1000
    n500 = change % 1000 // 500
    n100 = change % 1000 % 500 // 100
    n50 = change % 1000 % 500 % 100 // 50
    n10 = change % 1000 % 500 % 100 % 50 // 10

    if n1000:
        print('%4d원 : %2d개' % (1000, n1000))
    if n500:
        print('%4d원 : %2d개' % (500, n500))
    if n100:
        print('%4d원 : %2d개' % (100, n100))
    if n50:
        print('%4d원 : %2d개' % (50, n50))
    # if n10 > 0: 
    if n10 : 
        print('%4d원 : %2d개' % (10, n10))

    # print(f'1000원 : {change // 1000}개')
    # print('%4d원 : %d개' % (500, change // 500))

else :
    print(f'{-change}원이 부족합니다')
# Out:
# 거스름돈 : 5850원이다
# 1000원 :  5개
#  500원 :  1개
#  100원 :  3개
#   50원 :  1개

# %%
change = money - total
if change >= 0 : 
    print(f'거스름돈 : {change}원이다')

    # n1000 = change // 1000
    # change = change % 1000
    # n500 = change // 500
    # change = change % 500
    # n100 = change // 100

    print('%4d원 : %2d개' % (1000, change // 1000))
    # change = change % 1000
    change %= 1000
    print('%4d원 : %2d개' % (500, change // 500))
    change = change % 500
    print('%4d원 : %2d개' % (100, change // 100))
    change = change % 100
    print('%4d원 : %2d개' % (50, change // 50))
    change = change % 50
    print('%4d원 : %2d개' % (10, change // 10))

    # print(f'1000원 : {change // 1000}개')
    # print('%4d원 : %d개' % (500, change // 500))

else :
    print(f'{-change}원이 부족합니다')
# Out:
# 거스름돈 : 5870원이다
# 1000원 :  5개
#  500원 :  1개
#  100원 :  3개
#   50원 :  1개
#   10원 :  2개

# %% [markdown]
# 숫자 3개 입력받아 작은수에서 큰수순으로 출력

# %%
a,b,c = map(int, input('숫자 3개를 입력하시오').split(' '))

min = a
max = b
if a > b:
    min = b
    max = a

if c < min:
    print(f'{c}  {min}  {max}')
elif c < max:
    print(f'{min}  {c}  {max}')
else:
    print(f'{min}  {max}  {c}')
# Out:
# 1  2  3
